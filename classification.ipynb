# %% [markdown]
# ### Upload input data to MinIO

# %%
import os
import boto3

s3 = boto3.resource('s3',
                    #endpoint_url='http://127.0.0.1:61403',
                    #endpoint_url='http://127.0.0.1:30080',
                    endpoint_url='https://minio-api.digitalhub-dev.smartcommunitylab.it/',
                    aws_access_key_id='minio',
                    aws_secret_access_key='minio123',
                    aws_session_token=None,
                    config=boto3.session.Config(signature_version='s3v4'))

# %%
ipzs_bucket = s3.Bucket("ipzs")
input_folder = "/Users/erica/document-classification/input-folder/ipzs"
years = ["2014", "2015", "2016", "2017", "2018", "2019", "2020", "2021"]

for year in years:
    for root, subfolders, files in os.walk(input_folder + "/" + year):
        for item in files:
            if item.endswith(".json") or item.endswith(".csv"):
                fileNamePath = str(os.path.join(root,item))
                ipzs_bucket.upload_file(fileNamePath, fileNamePath.replace(input_folder + "/", ""))

# %%
for root, subfolders, files in os.walk(input_folder):
    for item in files:
        if item.startswith(".DS"):
            fileNamePath = str(os.path.join(root,item))
            print(fileNamePath)
            os.remove(fileNamePath)

# %% [markdown]
# ### Configure MLRun

# %%
import mlrun

# %%
#set path of MLRun API running on Minikube
#mlrun.set_environment("http://127.0.0.1:30070")
#set path of MLRun API running ok Kubernetes
mlrun.set_environment("https://mlrun-api.digitalhub-dev.smartcommunitylab.it", username="digitalhub-dev")

# %%
mlrun.get_secret_or_env("MLRUN_DBPATH")
# Out:
# 'http://127.0.0.1:30070'

# %% [markdown]
# ### Create a project

# %%
#project = mlrun.new_project("document-classification", context="./", overwrite=True, init_git=False, user_project=False)
project = mlrun.get_or_create_project("document-classification", context="./", init_git=False, user_project=False)
# Out:
# > 2023-03-30 11:35:45,930 [info] loaded project document-classification from MLRun DB

# %% [markdown]
# ### Register the pre-processing function and run it

# %%
preproc_fn = project.set_function(
    name="pre-processing",
    func="01-preprocessing_handlers.py",
    handler="parse_ipzs",
    kind="job",
    image="mlrun/mlrun", #includes sklearn, pandas, numpy
    #requirements=[] #list or path to a requirements.txt
)

# %%
project.save()

# %%
preproc_run = project.run_function(
    "pre-processing",
    #local=False,
    params={"bucket_name": "ipzs", "idPrefix": "ipzs-", "limit": 10, "max_documents": 250},
    outputs=["preprocessed_data"]
)
# Out:
# > 2023-03-29 14:49:04,898 [warning] it is recommended to use k8s secret (specify secret_name), specifying the aws_access_key/aws_secret_key directly is unsafe
# > 2023-03-29 14:49:04,981 [info] starting run pre-processing-parse_ipzs uid=ffd459a885e04e1cb0859b40332e18e9 DB=http://127.0.0.1:30070
# > 2023-03-29 14:49:05,342 [info] Job is running in the background, pod: pre-processing-parse-ipzs-5r99f
# INFO:root:s3_endpoint_url: http://minio.mlrun.svc.cluster.local:9000
# INFO:botocore.credentials:Found credentials in environment variables.
# INFO:botocore.credentials:Found credentials in environment variables.
# ERROR:root:20210623_21G00103 not in index
# ERROR:root:20210623_21G00097 not in index
# ERROR:root:20210623_21G00108 not in index
# ERROR:root:20210622_21G00096 not in index
# ERROR:root:20210622_21G00107 not in index
# ERROR:root:20210621_21G00104 not in index
# ERROR:root:20210618_21G00095 not in index
# ERROR:root:20210617_21G00092 not in index
# ERROR:root:20210616_21G00091 not in index
# ERROR:root:20210615_21G00094 not in index
# ERROR:root:20210614_21G00098 not in index
# ERROR:root:19880121_088G0020 not in index
# ERROR:root:19880121_088G0021 not in index
# ERROR:root:19880121_088G0018 not in index
# ERROR:root:19880120_088G0017 not in index
# ERROR:root:19880120_088G0023 not in index
# ERROR:root:19880120_088G0024 not in index
# ERROR:root:19880120_088G0001 not in index
# ERROR:root:19880119_088G0014 not in index
# ERROR:root:19880118_088G0013 not in index
# ERROR:root:19880116_088G0016 not in index
# ERROR:root:19880116_088G0015 not in index
# ERROR:root:19880114_088G0005 not in index
# ERROR:root:19880113_088G0012 not in index
# ERROR:root:19880113_088G0011 not in index
# ERROR:root:19880113_088G0010 not in index
# ERROR:root:19880113_088G0009 not in index
# ERROR:root:19880113_088G0008 not in index
# ERROR:root:19880112_088G0006 not in index
# ERROR:root:19880112_087G0748 not in index
# ERROR:root:19880108_088G0004 not in index
# ERROR:root:19880108_087G0738 not in index
# ERROR:root:19880107_087G0758 not in index
# ERROR:root:19880107_087G0756 not in index
# ERROR:root:19880107_088G0002 not in index
# ERROR:root:19880107_088G0003 not in index
# ERROR:root:19880107_087G0757 not in index
# ERROR:root:19880105_087G0754 not in index
# ERROR:root:19880105_087G0755 not in index
# ERROR:root:19880104_087G0753 not in index
# ERROR:root:19880102_087G0742 not in index
# ERROR:root:19880102_087G0741 not in index
# INFO:root:Length of result: 250
# INFO:root:Length of result: 88
# > 2023-03-29 12:49:16,715 [info] To track results use the CLI: {'info_cmd': 'mlrun get run ffd459a885e04e1cb0859b40332e18e9 -p document-classification', 'logs_cmd': 'mlrun logs ffd459a885e04e1cb0859b40332e18e9 -p document-classification'}
# > 2023-03-29 12:49:16,716 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="ffd459a885e04e1cb0859b40332e18e9">...2e18e9</div></td>
#       <td>0</td>
#       <td>Mar 29 12:49:11</td>
#       <td>completed</td>
#       <td>pre-processing-parse_ipzs</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=pre-processing-parse-ipzs-5r99f</div></td>
#       <td></td>
#       <td><div class="dictlist">bucket_name=ipzs</div><div class="dictlist">idPrefix=ipzs-</div><div class="dictlist">limit=10</div><div class="dictlist">max_documents=250</div></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/pre-processing-parse_ipzs/0/preprocessed_data.json">preprocessed_data</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result8e0a1914-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result8e0a1914-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result8e0a1914" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result8e0a1914-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 14:49:18,544 [info] run executed, status=completed

# %%
preproc_run.outputs["preprocessed_data"]
# Out:
# 's3://mlrun/projects/document-classification/artifacts/pre-processing-parse_ipzs/0/preprocessed_data.json'

# %% [markdown]
# ### Register the parsing function and run it
#
# **NOTE**: building/auto-building images does not work on ARM because the resulting images are for ARM but AMD images are required. Manually building images and loading them on DockerHub is the current workaround.

# %%
#image has been built with:
# docker build -t classification-parsing:latest -<<EOF
# FROM mlrun/mlrun:1.2.1
# RUN pip install tqdm==4.61.1
# RUN pip install requests==2.25.1
# RUN pip install stanza==1.4.2
# EOF
parsing_fn = project.set_function(
    name="parsing",
    func="02-parsing_handlers.py",
    handler="parse",
    kind="job",
    image="ertomaselli/classification-parsing:latest"
)

#for VM with autobuild
# parsing_fn = project.set_function(
#     name="parsing",
#     func="02-parsing_handlers.py",
#     handler="parse",
#     kind="job",
#     image="mlrun/mlrun",
#     requirements=["tqdm==4.61.1", "requests==2.25.1", "stanza==1.4.2"] #list or path to a requirements.txt
# )

# %%
project.save()

# %%
parsing_run = project.run_function(
    "parsing",
    inputs={"input_file": preproc_run.outputs["preprocessed_data"]},
    params={"tint_url": None}
)
# Out:
# > 2023-03-29 15:16:22,857 [warning] it is recommended to use k8s secret (specify secret_name), specifying the aws_access_key/aws_secret_key directly is unsafe
# > 2023-03-29 15:16:22,902 [info] starting run parsing-parse uid=3950c35f608e4a3da05da02d357ddbef DB=http://127.0.0.1:30070
# > 2023-03-29 15:16:23,138 [info] Job is running in the background, pod: parsing-parse-n7q2m
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 79.5MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/tokenize/combined.pt: 100%|██████████| 649k/649k [00:00<00:00, 20.7MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/mwt/combined.pt: 100%|██████████| 1.16M/1.16M [00:00<00:00, 30.1MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/pos/combined.pt: 100%|██████████| 34.9M/34.9M [00:00<00:00, 121MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/lemma/combined.pt: 100%|██████████| 5.71M/5.71M [00:00<00:00, 61.5MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/pretrain/combined.pt: 100%|██████████| 107M/107M [00:00<00:00, 300MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/forward_charlm/conll17.pt: 100%|██████████| 22.6M/22.6M [00:00<00:00, 155MB/s]
# Downloading https://huggingface.co/stanfordnlp/stanza-it/resolve/v1.4.1/models/backward_charlm/conll17.pt: 100%|██████████| 22.6M/22.6M [00:04<00:00, 4.95MB/s]
# INFO:stanza:Loading these models for language: it (Italian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | mwt       | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Done loading processors!
# INFO:root:Loading texts
# INFO:root:Performing NLP
# ipzs-20100108_009G0198: 100%|██████████| 88/88 [00:41<00:00,  2.13it/s]
# INFO:root:Creating zipped folder to log as artifact
# INFO:root:Errors: []
# > 2023-03-29 13:19:31,265 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 3950c35f608e4a3da05da02d357ddbef -p document-classification', 'logs_cmd': 'mlrun logs 3950c35f608e4a3da05da02d357ddbef -p document-classification'}
# > 2023-03-29 13:19:31,266 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="3950c35f608e4a3da05da02d357ddbef">...7ddbef</div></td>
#       <td>0</td>
#       <td>Mar 29 13:18:37</td>
#       <td>completed</td>
#       <td>parsing-parse</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=parsing-parse-n7q2m</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/pre-processing-parse_ipzs/0/preprocessed_data.json">input_file</div></td>
#       <td><div class="dictlist">tint_url=None</div></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/parsing-parse/0/tint_files.zip">tint_files</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result9f729a29-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result9f729a29-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result9f729a29" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result9f729a29-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:19:40,928 [info] run executed, status=completed

# %%
parsing_run.outputs
# Out:
# {'tint_files': 's3://mlrun/projects/document-classification/artifacts/parsing-parse/0/tint_files.zip'}

# %% [markdown]
# ### Register the function that extracts test sets and run it

# %%
extracting_fn = project.set_function(
    name="extracting_test",
    func="03-extracting_test_handlers.py",
    handler="extract_test_sets",
    kind="job",
    image="mlrun/mlrun"
)

# %%
project.save()

# %%
extracting_run = project.run_function(
    "extracting_test",
    inputs={"input_file": preproc_run.outputs["preprocessed_data"], "tint_files": parsing_run.outputs["tint_files"]},
    params={"testRatio": 0.2, "devRatio": 0.2}
)
# Out:
# > 2023-03-29 15:20:19,653 [warning] it is recommended to use k8s secret (specify secret_name), specifying the aws_access_key/aws_secret_key directly is unsafe
# > 2023-03-29 15:20:19,740 [info] starting run extracting-test-extract_test_sets uid=7e3bb9222afe4f118c3229d6bdadff11 DB=http://127.0.0.1:30070
# > 2023-03-29 15:20:19,989 [info] Job is running in the background, pod: extracting-test-extract-test-sets-v6x87
# INFO:root:Loading JSON file
# INFO:root:Downloading and extracting tint_files.zip
# INFO:root:Shuffling data
# INFO:root:Extracting texts
# INFO:root:Saving test list
# INFO:root:Saving dev list
# INFO:root:Train size: 50
# INFO:root:Test size: 19
# INFO:root:Dev size: 19
# > 2023-03-29 13:20:26,284 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 7e3bb9222afe4f118c3229d6bdadff11 -p document-classification', 'logs_cmd': 'mlrun logs 7e3bb9222afe4f118c3229d6bdadff11 -p document-classification'}
# > 2023-03-29 13:20:26,285 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="7e3bb9222afe4f118c3229d6bdadff11">...adff11</div></td>
#       <td>0</td>
#       <td>Mar 29 13:20:25</td>
#       <td>completed</td>
#       <td>extracting-test-extract_test_sets</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=extracting-test-extract-test-sets-v6x87</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/pre-processing-parse_ipzs/0/preprocessed_data.json">input_file</div><div title="s3://mlrun/projects/document-classification/artifacts/parsing-parse/0/tint_files.zip">tint_files</div></td>
#       <td><div class="dictlist">testRatio=0.2</div><div class="dictlist">devRatio=0.2</div></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/testlist.txt">testlist</div><div title="s3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/devlist.txt">devlist</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultf7fa18b3-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultf7fa18b3-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultf7fa18b3" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultf7fa18b3-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:20:29,464 [info] run executed, status=completed

# %%
extracting_run.outputs
# Out:
# {'testlist': 's3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/testlist.txt',
#  'devlist': 's3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/devlist.txt'}

# %% [markdown]
# ### Register the function for saving data and run it

# %%
saving_fn = project.set_function(
    name="saving_data",
    func="04-saving_data_handlers.py",
    handler="save_data",
    kind="job",
    image="ertomaselli/classification-parsing:latest"
)

# %%
project.save()

# %%
saving_run = project.run_function(
    "saving_data",
    inputs={"input_file": preproc_run.outputs["preprocessed_data"],
            "test_list_file": extracting_run.outputs["testlist"],
            "dev_list_file": extracting_run.outputs["devlist"],
            "tint_files": parsing_run.outputs["tint_files"]}
)
# Out:
# > 2023-03-29 15:21:25,055 [warning] it is recommended to use k8s secret (specify secret_name), specifying the aws_access_key/aws_secret_key directly is unsafe
# > 2023-03-29 15:21:25,138 [info] starting run saving-data-save_data uid=ff53af47ae0e4f06bb1fb0f1639e7b50 DB=http://127.0.0.1:30070
# > 2023-03-29 15:21:25,393 [info] Job is running in the background, pod: saving-data-save-data-55lrk
# INFO:root:Loading JSON file
# INFO:root:Downloading and extracting tint_files.zip
# INFO:root:Extracting texts
# 100%|██████████| 88/88 [00:00<00:00, 1185.00it/s]
# INFO:root:Saving file
# > 2023-03-29 13:21:32,209 [info] To track results use the CLI: {'info_cmd': 'mlrun get run ff53af47ae0e4f06bb1fb0f1639e7b50 -p document-classification', 'logs_cmd': 'mlrun logs ff53af47ae0e4f06bb1fb0f1639e7b50 -p document-classification'}
# > 2023-03-29 13:21:32,209 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="ff53af47ae0e4f06bb1fb0f1639e7b50">...9e7b50</div></td>
#       <td>0</td>
#       <td>Mar 29 13:21:31</td>
#       <td>completed</td>
#       <td>saving-data-save_data</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=saving-data-save-data-55lrk</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/pre-processing-parse_ipzs/0/preprocessed_data.json">input_file</div><div title="s3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/testlist.txt">test_list_file</div><div title="s3://mlrun/projects/document-classification/artifacts/extracting-test-extract_test_sets/0/devlist.txt">dev_list_file</div><div title="s3://mlrun/projects/document-classification/artifacts/parsing-parse/0/tint_files.zip">tint_files</div></td>
#       <td></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/saving-data-save_data/0/complete.json">complete</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultf7a6aff2-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultf7a6aff2-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultf7a6aff2" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultf7a6aff2-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:21:34,864 [info] run executed, status=completed

# %%
saving_run.outputs
# Out:
# {'complete': 's3://mlrun/projects/document-classification/artifacts/saving-data-save_data/0/complete.json'}

# %% [markdown]
# ### Register the filtering function and save it

# %%
filtering_fn = project.set_function(
    name="filtering",
    func="05-filtering_handlers.py",
    handler="filter",
    kind="job",
    image="ertomaselli/classification-parsing:latest"
)

# %%
project.save()

# %%
filtering_run = project.run_function(
    "filtering",
    inputs={"complete_json_file": saving_run.outputs["complete"]},
    params={"minFreq": 3}
)
# Out:
# > 2023-03-29 15:21:51,592 [warning] it is recommended to use k8s secret (specify secret_name), specifying the aws_access_key/aws_secret_key directly is unsafe
# > 2023-03-29 15:21:51,686 [info] starting run filtering-filter uid=840f5151dd9348a781de14101a21956d DB=http://127.0.0.1:30070
# > 2023-03-29 15:21:51,896 [info] Job is running in the background, pod: filtering-filter-twhzr
# INFO:root:Loading JSON file
# INFO:root:goodTokens: writing unfiltered files
# INFO:root:goodTokens: 50 documents
# INFO:root:goodTokens: 3 labels
# INFO:root:goodTokens-by_document: extracting frequencies
# INFO:root:goodTokens-by_document: extracting stopwords
# INFO:root:goodTokens-by_document: stopwords size: 246
# INFO:root:goodTokens-by_document: removing stopwords
# INFO:root:goodTokens-by_document: calculating TF-IDF
# INFO:root:goodTokens-by_document: collecting weights
# INFO:root:goodTokens-by_document: ok words size: 51
# INFO:root:goodTokens-by_document: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 235544.83it/s]
# INFO:root:goodTokens-by_label: extracting frequencies
# INFO:root:goodTokens-by_label: extracting stopwords
# INFO:root:goodTokens-by_label: stopwords size: 246
# INFO:root:goodTokens-by_label: removing stopwords
# INFO:root:goodTokens-by_label: calculating TF-IDF
# INFO:root:goodTokens-by_label: collecting weights
# INFO:root:goodTokens-by_label: ok words size: 40
# INFO:root:goodTokens-by_label: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 271196.73it/s]
# INFO:root:allLemmas: writing unfiltered files
# INFO:root:allLemmas: 50 documents
# INFO:root:allLemmas: 3 labels
# INFO:root:allLemmas-by_document: extracting frequencies
# INFO:root:allLemmas-by_document: extracting stopwords
# INFO:root:allLemmas-by_document: stopwords size: 371
# INFO:root:allLemmas-by_document: removing stopwords
# INFO:root:allLemmas-by_document: calculating TF-IDF
# INFO:root:allLemmas-by_document: collecting weights
# INFO:root:allLemmas-by_document: ok words size: 159
# INFO:root:allLemmas-by_document: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 138550.58it/s]
# INFO:root:allLemmas-by_label: extracting frequencies
# INFO:root:allLemmas-by_label: extracting stopwords
# INFO:root:allLemmas-by_label: stopwords size: 371
# INFO:root:allLemmas-by_label: removing stopwords
# INFO:root:allLemmas-by_label: calculating TF-IDF
# INFO:root:allLemmas-by_label: collecting weights
# INFO:root:allLemmas-by_label: ok words size: 141
# INFO:root:allLemmas-by_label: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 171196.08it/s]
# INFO:root:allTokens: writing unfiltered files
# INFO:root:allTokens: 50 documents
# INFO:root:allTokens: 3 labels
# INFO:root:allTokens-by_document: extracting frequencies
# INFO:root:allTokens-by_document: extracting stopwords
# INFO:root:allTokens-by_document: stopwords size: 413
# INFO:root:allTokens-by_document: removing stopwords
# INFO:root:allTokens-by_document: calculating TF-IDF
# INFO:root:allTokens-by_document: collecting weights
# INFO:root:allTokens-by_document: ok words size: 167
# INFO:root:allTokens-by_document: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 147286.01it/s]
# INFO:root:allTokens-by_label: extracting frequencies
# INFO:root:allTokens-by_label: extracting stopwords
# INFO:root:allTokens-by_label: stopwords size: 413
# INFO:root:allTokens-by_label: removing stopwords
# INFO:root:allTokens-by_label: calculating TF-IDF
# INFO:root:allTokens-by_label: collecting weights
# INFO:root:allTokens-by_label: ok words size: 147
# INFO:root:allTokens-by_label: writing filtered files
# 100%|██████████| 88/88 [00:00<00:00, 167772.16it/s]
# INFO:root:Creating zipped folder to log as artifact
# > 2023-03-29 13:21:56,626 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 840f5151dd9348a781de14101a21956d -p document-classification', 'logs_cmd': 'mlrun logs 840f5151dd9348a781de14101a21956d -p document-classification'}
# > 2023-03-29 13:21:56,627 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="840f5151dd9348a781de14101a21956d">...21956d</div></td>
#       <td>0</td>
#       <td>Mar 29 13:21:56</td>
#       <td>completed</td>
#       <td>filtering-filter</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=filtering-filter-twhzr</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/saving-data-save_data/0/complete.json">complete_json_file</div></td>
#       <td><div class="dictlist">minFreq=3</div></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/filtering-filter/0/filtering_files.zip">filtering_files</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result17502f5c-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result17502f5c-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result17502f5c" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="result17502f5c-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:21:58,133 [info] run executed, status=completed

# %%
filtering_run.outputs
# Out:
# {'filtering_files': 's3://mlrun/projects/document-classification/artifacts/filtering-filter/0/filtering_files.zip'}

# %% [markdown]
# ### Register the training function and run it

# %%
#image has been built with:
# docker build -t classification-training:latest -<<EOF
# FROM mlrun/mlrun:1.2.1
# RUN apt-get update
# RUN apt-get install build-essential -y
# RUN pip install fasttext
# EOF
training_fn = project.set_function(
    name="training",
    func="training_handlers.py",
    handler="train",
    kind="job",
    image="ertomaselli/classification-training:latest"
)

# %%
project.save()

# %%
training_run = project.run_function(
    "training",
    inputs={"training_files": filtering_run.outputs["filtering_files"]}
)
# Out:
# > 2023-03-29 15:38:04,255 [info] starting run training-train uid=4fe9cf5d9cf349cbbeb2b81e6a3c8a8b DB=http://127.0.0.1:30070
# > 2023-03-29 15:38:05,315 [info] Job is running in the background, pod: training-train-69qk5
# INFO:root:Downloading and extracting filtering_files.zip
# INFO:root:Creating goodTokens model
# Read 0M words
# Number of words:  301
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   29295 lr:  0.000000 avg.loss:  0.142260 ETA:   0h 0m 0s
# INFO:root:Testing goodTokens model
# INFO:root:Predicting with goodTokens_unfiltered_model.bin model for the whole test data
# INFO:root:Logging goodTokens artifacts
# INFO:root:Creating goodTokens_by_document model
# Read 0M words
# Number of words:  52
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   15941 lr:  0.000000 avg.loss:      -nan ETA:   0h 0m 0s
# INFO:root:Testing goodTokens_by_document model
# INFO:root:Predicting with goodTokens_by_document_filtered_model.bin model for the whole test data
# INFO:root:Logging goodTokens_by_document artifacts
# INFO:root:Creating goodTokens_by_label model
# Read 0M words
# Number of words:  41
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   15240 lr:  0.000000 avg.loss:      -nan ETA:   0h 0m 0s
# INFO:root:Testing goodTokens_by_label model
# INFO:root:Predicting with goodTokens_by_label_filtered_model.bin model for the whole test data
# INFO:root:Logging goodTokens_by_label artifacts
# INFO:root:Creating allLemmas model
# Read 0M words
# Number of words:  560
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   86191 lr:  0.000000 avg.loss:  0.077854 ETA:   0h 0m 0s
# INFO:root:Testing allLemmas model
# INFO:root:Predicting with allLemmas_unfiltered_model.bin model for the whole test data
# INFO:root:Logging allLemmas artifacts
# INFO:root:Creating allLemmas_by_document model
# Read 0M words
# Number of words:  160
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   26201 lr:  0.000000 avg.loss:  0.108531 ETA:   0h 0m 0s
# INFO:root:Testing allLemmas_by_document model
# INFO:root:Predicting with allLemmas_by_document_filtered_model.bin model for the whole test data
# INFO:root:Logging allLemmas_by_document artifacts
# INFO:root:Creating allLemmas_by_label model
# Read 0M words
# Number of words:  142
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   24353 lr:  0.000000 avg.loss:  0.005065 ETA:   0h 0m 0s
# INFO:root:Testing allLemmas_by_label model
# INFO:root:Predicting with allLemmas_by_label_filtered_model.bin model for the whole test data
# INFO:root:Logging allLemmas_by_label artifacts
# INFO:root:Creating allTokens model
# Read 0M words
# Number of words:  617
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   77676 lr:  0.000000 avg.loss:  0.248465 ETA:   0h 0m 0s
# INFO:root:Testing allTokens model
# INFO:root:Predicting with allTokens_unfiltered_model.bin model for the whole test data
# INFO:root:Logging allTokens artifacts
# INFO:root:Creating allTokens_by_document model
# Read 0M words
# Number of words:  167
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   28145 lr:  0.000000 avg.loss:      -nan ETA:   0h 0m 0s
# INFO:root:Testing allTokens_by_document model
# INFO:root:Predicting with allTokens_by_document_filtered_model.bin model for the whole test data
# INFO:root:Logging allTokens_by_document artifacts
# INFO:root:Creating allTokens_by_label model
# Read 0M words
# Number of words:  148
# Number of labels: 3
# Progress: 100.0% words/sec/thread:   24594 lr:  0.000000 avg.loss:  0.164782 ETA:   0h 0m 0s
# INFO:root:Testing allTokens_by_label model
# INFO:root:Predicting with allTokens_by_label_filtered_model.bin model for the whole test data
# INFO:root:Logging allTokens_by_label artifacts
# INFO:root:Creating zipped folder to log as artifact
# > 2023-03-29 13:38:22,795 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 4fe9cf5d9cf349cbbeb2b81e6a3c8a8b -p document-classification', 'logs_cmd': 'mlrun logs 4fe9cf5d9cf349cbbeb2b81e6a3c8a8b -p document-classification'}
# > 2023-03-29 13:38:22,796 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="4fe9cf5d9cf349cbbeb2b81e6a3c8a8b">...3c8a8b</div></td>
#       <td>0</td>
#       <td>Mar 29 13:38:19</td>
#       <td>completed</td>
#       <td>training-train</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=training-train-69qk5</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/filtering-filter/0/filtering_files.zip">training_files</div></td>
#       <td></td>
#       <td></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/goodTokens_unfiltered_model/">goodTokens_unfiltered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/goodTokens_by_document_filtered_model/">goodTokens_by_document_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/goodTokens_by_label_filtered_model/">goodTokens_by_label_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allLemmas_unfiltered_model/">allLemmas_unfiltered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allLemmas_by_document_filtered_model/">allLemmas_by_document_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allLemmas_by_label_filtered_model/">allLemmas_by_label_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allTokens_unfiltered_model/">allTokens_unfiltered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allTokens_by_document_filtered_model/">allTokens_by_document_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/allTokens_by_label_filtered_model/">allTokens_by_label_filtered_model</div><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/results.zip">results</div></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="resultf823bc0c-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="resultf823bc0c-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="resultf823bc0c" class="close clickable">&times;</span>
#     </div>
#     <iframe class="fileview" id="resultf823bc0c-body"></iframe>
#   </div>
# </div>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:38:25,376 [info] run executed, status=completed

# %%
training_run.outputs
# Out:
# {'goodTokens_unfiltered_model': 'store://artifacts/document-classification/training-train_goodTokens_unfiltered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'goodTokens_by_document_filtered_model': 'store://artifacts/document-classification/training-train_goodTokens_by_document_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'goodTokens_by_label_filtered_model': 'store://artifacts/document-classification/training-train_goodTokens_by_label_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allLemmas_unfiltered_model': 'store://artifacts/document-classification/training-train_allLemmas_unfiltered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allLemmas_by_document_filtered_model': 'store://artifacts/document-classification/training-train_allLemmas_by_document_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allLemmas_by_label_filtered_model': 'store://artifacts/document-classification/training-train_allLemmas_by_label_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allTokens_unfiltered_model': 'store://artifacts/document-classification/training-train_allTokens_unfiltered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allTokens_by_document_filtered_model': 'store://artifacts/document-classification/training-train_allTokens_by_document_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'allTokens_by_label_filtered_model': 'store://artifacts/document-classification/training-train_allTokens_by_label_filtered_model:4fe9cf5d9cf349cbbeb2b81e6a3c8a8b',
#  'results': 's3://mlrun/projects/document-classification/artifacts/training-train/0/results.zip'}

# %% [markdown]
# ### Register the evaluation function and run it

# %%
evaluation_fn = project.set_function(
    name="evaluation",
    func="06-evaluation_handlers.py",
    handler="evaluate",
    kind="job",
    image="mlrun/mlrun"
)

# %%
project.save()

# %%
evaluation_run = project.run_function(
    "evaluation",
    inputs={"pred_files": training_run.outputs["results"], "gold_files": filtering_run.outputs["filtering_files"]},
    params={"show_cm": True}
)
# Out:
# > 2023-03-29 15:38:48,028 [info] starting run evaluation-evaluate uid=151456a65da344008648d1c5d9f76118 DB=http://127.0.0.1:30070
# > 2023-03-29 15:38:48,339 [info] Job is running in the background, pod: evaluation-evaluate-8jc8b
# INFO:root:Downloading and extracting pred_files
# INFO:root:Downloading and extracting gold_files
# INFO:root:Pred file: results/goodTokens_by_document_filtered.results.txt
# INFO:root:Test file: filtering_files/goodTokens_by_document_filtered.test.txt
# INFO:root:Pred file: results/allLemmas_by_label_filtered.results.txt
# INFO:root:Test file: filtering_files/allLemmas_by_label_filtered.test.txt
# INFO:root:Pred file: results/allLemmas_by_document_filtered.results.txt
# INFO:root:Test file: filtering_files/allLemmas_by_document_filtered.test.txt
# INFO:root:Pred file: results/allTokens_by_label_filtered.results.txt
# INFO:root:Test file: filtering_files/allTokens_by_label_filtered.test.txt
# INFO:root:Pred file: results/allTokens_unfiltered.results.txt
# INFO:root:Test file: filtering_files/allTokens_unfiltered.test.txt
# INFO:root:Pred file: results/goodTokens_unfiltered.results.txt
# INFO:root:Test file: filtering_files/goodTokens_unfiltered.test.txt
# INFO:root:Pred file: results/allTokens_by_document_filtered.results.txt
# INFO:root:Test file: filtering_files/allTokens_by_document_filtered.test.txt
# INFO:root:Pred file: results/allLemmas_unfiltered.results.txt
# INFO:root:Test file: filtering_files/allLemmas_unfiltered.test.txt
# INFO:root:Pred file: results/goodTokens_by_label_filtered.results.txt
# INFO:root:Test file: filtering_files/goodTokens_by_label_filtered.test.txt
# > 2023-03-29 13:38:56,917 [info] To track results use the CLI: {'info_cmd': 'mlrun get run 151456a65da344008648d1c5d9f76118 -p document-classification', 'logs_cmd': 'mlrun logs 151456a65da344008648d1c5d9f76118 -p document-classification'}
# > 2023-03-29 13:38:56,918 [info] run executed, status=completed
# final state: completed
# <style>
# .dictlist {
#   background-color: #4EC64B;
#   text-align: center;
#   margin: 4px;
#   border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;}
# .artifact {
#   cursor: pointer;
#   background-color: #4EC64B;
#   text-align: left;
#   margin: 4px; border-radius: 3px; padding: 0px 3px 1px 3px; display: inline-block;
# }
# div.block.hidden {
#   display: none;
# }
# .clickable {
#   cursor: pointer;
# }
# .ellipsis {
#   display: inline-block;
#   max-width: 60px;
#   white-space: nowrap;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# .master-wrapper {
#   display: flex;
#   flex-flow: row nowrap;
#   justify-content: flex-start;
#   align-items: stretch;
# }
# .master-tbl {
#   flex: 3
# }
# .master-wrapper > div {
#   margin: 4px;
#   padding: 10px;
# }
# iframe.fileview {
#   border: 0 none;
#   height: 100%;
#   width: 100%;
#   white-space: pre-wrap;
# }
# .pane-header-title {
#   width: 80%;
#   font-weight: 500;
# }
# .pane-header {
#   line-height: 1;
#   background-color: #4EC64B;
#   padding: 3px;
# }
# .pane-header .close {
#   font-size: 20px;
#   font-weight: 700;
#   float: right;
#   margin-top: -5px;
# }
# .master-wrapper .right-pane {
#   border: 1px inset silver;
#   width: 40%;
#   min-height: 300px;
#   flex: 3
#   min-width: 500px;
# }
# .master-wrapper * {
#   box-sizing: border-box;
# }
# </style><script>
# function copyToClipboard(fld) {
#     if (document.queryCommandSupported && document.queryCommandSupported('copy')) {
#         var textarea = document.createElement('textarea');
#         textarea.textContent = fld.innerHTML;
#         textarea.style.position = 'fixed';
#         document.body.appendChild(textarea);
#         textarea.select();
#
#         try {
#             return document.execCommand('copy'); // Security exception may be thrown by some browsers.
#         } catch (ex) {
#
#         } finally {
#             document.body.removeChild(textarea);
#         }
#     }
# }
# function expandPanel(el) {
#   const panelName = "#" + el.getAttribute('paneName');
#   console.log(el.title);
#
#   document.querySelector(panelName + "-title").innerHTML = el.title
#   iframe = document.querySelector(panelName + "-body");
#
#   const tblcss = `<style> body { font-family: Arial, Helvetica, sans-serif;}
#     #csv { margin-bottom: 15px; }
#     #csv table { border-collapse: collapse;}
#     #csv table td { padding: 4px 8px; border: 1px solid silver;} </style>`;
#
#   function csvToHtmlTable(str) {
#     return '<div id="csv"><table><tr><td>' +  str.replace(/[\n\r]+$/g, '').replace(/[\n\r]+/g, '</td></tr><tr><td>')
#       .replace(/,/g, '</td><td>') + '</td></tr></table></div>';
#   }
#
#   function reqListener () {
#     if (el.title.endsWith(".csv")) {
#       iframe.setAttribute("srcdoc", tblcss + csvToHtmlTable(this.responseText));
#     } else {
#       iframe.setAttribute("srcdoc", this.responseText);
#     }
#     console.log(this.responseText);
#   }
#
#   const oReq = new XMLHttpRequest();
#   oReq.addEventListener("load", reqListener);
#   oReq.open("GET", el.title);
#   oReq.send();
#
#
#   //iframe.src = el.title;
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (resultPane.classList.contains("hidden")) {
#     resultPane.classList.remove("hidden");
#   }
# }
# function closePanel(el) {
#   const panelName = "#" + el.getAttribute('paneName')
#   const resultPane = document.querySelector(panelName + "-pane");
#   if (!resultPane.classList.contains("hidden")) {
#     resultPane.classList.add("hidden");
#   }
# }
#
# </script>
# <div class="master-wrapper">
#   <div class="block master-tbl"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>project</th>
#       <th>uid</th>
#       <th>iter</th>
#       <th>start</th>
#       <th>state</th>
#       <th>name</th>
#       <th>labels</th>
#       <th>inputs</th>
#       <th>parameters</th>
#       <th>results</th>
#       <th>artifacts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>document-classification</td>
#       <td><div title="151456a65da344008648d1c5d9f76118">...f76118</div></td>
#       <td>0</td>
#       <td>Mar 29 13:38:56</td>
#       <td>completed</td>
#       <td>evaluation-evaluate</td>
#       <td><div class="dictlist">kind=job</div><div class="dictlist">owner=erica</div><div class="dictlist">mlrun/client_version=1.2.1</div><div class="dictlist">host=evaluation-evaluate-8jc8b</div></td>
#       <td><div title="s3://mlrun/projects/document-classification/artifacts/training-train/0/results.zip">pred_files</div><div title="s3://mlrun/projects/document-classification/artifacts/filtering-filter/0/filtering_files.zip">gold_files</div></td>
#       <td><div class="dictlist">show_cm=True</div></td>
#       <td><div class="dictlist">goodTokens_by_document_filtered_macro=0.9157894736842106</div><div class="dictlist">goodTokens_by_document_filtered_micro=0.9473684210526315</div><div class="dictlist">goodTokens_by_document_filtered_weighted=0.9434903047091412</div><div class="dictlist">goodTokens_by_document_filtered_confusion_matrix={}</div><div class="dictlist">allLemmas_by_label_filtered_macro=0.9111111111111111</div><div class="dictlist">allLemmas_by_label_filtered_micro=0.9473684210526315</div><div class="dictlist">allLemmas_by_label_filtered_weighted=0.9438596491228071</div><div class="dictlist">allLemmas_by_label_filtered_confusion_matrix={}</div><div class="dictlist">allLemmas_by_document_filtered_macro=0.9157894736842106</div><div class="dictlist">allLemmas_by_document_filtered_micro=0.9473684210526315</div><div class="dictlist">allLemmas_by_document_filtered_weighted=0.9434903047091412</div><div class="dictlist">allLemmas_by_document_filtered_confusion_matrix={}</div><div class="dictlist">allTokens_by_label_filtered_macro=0.7916666666666666</div><div class="dictlist">allTokens_by_label_filtered_micro=0.8947368421052632</div><div class="dictlist">allTokens_by_label_filtered_weighted=0.875</div><div class="dictlist">allTokens_by_label_filtered_confusion_matrix={'__label__A0330': {'Total': 3, 'Errors': 2, 'Ratio': 0.6666666666666666, 'Errors_matrix': {'__label__A1810': 2}}}</div><div class="dictlist">allTokens_unfiltered_macro=0.9157894736842106</div><div class="dictlist">allTokens_unfiltered_micro=0.9473684210526315</div><div class="dictlist">allTokens_unfiltered_weighted=0.9434903047091412</div><div class="dictlist">allTokens_unfiltered_confusion_matrix={}</div><div class="dictlist">goodTokens_unfiltered_macro=0.9111111111111111</div><div class="dictlist">goodTokens_unfiltered_micro=0.9473684210526315</div><div class="dictlist">goodTokens_unfiltered_weighted=0.9438596491228071</div><div class="dictlist">goodTokens_unfiltered_confusion_matrix={}</div><div class="dictlist">allTokens_by_document_filtered_macro=0.7935672514619884</div><div class="dictlist">allTokens_by_document_filtered_micro=0.8947368421052632</div><div class="dictlist">allTokens_by_document_filtered_weighted=0.8715604801477377</div><div class="dictlist">allTokens_by_document_filtered_confusion_matrix={}</div><div class="dictlist">allLemmas_unfiltered_macro=0.9111111111111111</div><div class="dictlist">allLemmas_unfiltered_micro=0.9473684210526315</div><div class="dictlist">allLemmas_unfiltered_weighted=0.9438596491228071</div><div class="dictlist">allLemmas_unfiltered_confusion_matrix={}</div><div class="dictlist">goodTokens_by_label_filtered_macro=0.8055555555555557</div><div class="dictlist">goodTokens_by_label_filtered_micro=0.8421052631578947</div><div class="dictlist">goodTokens_by_label_filtered_weighted=0.8421052631578947</div><div class="dictlist">goodTokens_by_label_filtered_confusion_matrix={}</div></td>
#       <td></td>
#     </tr>
#   </tbody>
# </table>
# </div></div>
#   <div id="result60934d32-pane" class="right-pane block hidden">
#     <div class="pane-header">
#       <span id="result60934d32-title" class="pane-header-title">Title</span>
#       <span onclick="closePanel(this)" paneName="result60934d32" class="close clickable">&times;</span>
# <b> > to track results use the .show() or .logs() methods </b>
# > 2023-03-29 15:38:57,825 [info] run executed, status=completed

# %%
evaluation_run.outputs
# Out:
# {'goodTokens_by_document_filtered_macro': 0.9157894736842106,
#  'goodTokens_by_document_filtered_micro': 0.9473684210526315,
#  'goodTokens_by_document_filtered_weighted': 0.9434903047091412,
#  'goodTokens_by_document_filtered_confusion_matrix': {},
#  'allLemmas_by_label_filtered_macro': 0.9111111111111111,
#  'allLemmas_by_label_filtered_micro': 0.9473684210526315,
#  'allLemmas_by_label_filtered_weighted': 0.9438596491228071,
#  'allLemmas_by_label_filtered_confusion_matrix': {},
#  'allLemmas_by_document_filtered_macro': 0.9157894736842106,
#  'allLemmas_by_document_filtered_micro': 0.9473684210526315,
#  'allLemmas_by_document_filtered_weighted': 0.9434903047091412,
#  'allLemmas_by_document_filtered_confusion_matrix': {},
#  'allTokens_by_label_filtered_macro': 0.7916666666666666,
#  'allTokens_by_label_filtered_micro': 0.8947368421052632,
#  'allTokens_by_label_filtered_weighted': 0.875,
#  'allTokens_by_label_filtered_confusion_matrix': {'__label__A0330': {'Total': 3,
#    'Errors': 2,
#    'Ratio': 0.6666666666666666,
#    'Errors_matrix': {'__label__A1810': 2}}},
#  'allTokens_unfiltered_macro': 0.9157894736842106,
#  'allTokens_unfiltered_micro': 0.9473684210526315,
#  'allTokens_unfiltered_weighted': 0.9434903047091412,
#  'allTokens_unfiltered_confusion_matrix': {},
#  'goodTokens_unfiltered_macro': 0.9111111111111111,
#  'goodTokens_unfiltered_micro': 0.9473684210526315,
#  'goodTokens_unfiltered_weighted': 0.9438596491228071,
#  'goodTokens_unfiltered_confusion_matrix': {},
#  'allTokens_by_document_filtered_macro': 0.7935672514619884,
#  'allTokens_by_document_filtered_micro': 0.8947368421052632,
#  'allTokens_by_document_filtered_weighted': 0.8715604801477377,
#  'allTokens_by_document_filtered_confusion_matrix': {},
#  'allLemmas_unfiltered_macro': 0.9111111111111111,
#  'allLemmas_unfiltered_micro': 0.9473684210526315,
#  'allLemmas_unfiltered_weighted': 0.9438596491228071,
#  'allLemmas_unfiltered_confusion_matrix': {},
#  'goodTokens_by_label_filtered_macro': 0.8055555555555557,
#  'goodTokens_by_label_filtered_micro': 0.8421052631578947,
#  'goodTokens_by_label_filtered_weighted': 0.8421052631578947,
#  'goodTokens_by_label_filtered_confusion_matrix': {}}

# %% [markdown]
# ### Define and run a pipeline

# %%
project.set_workflow(
    "classification",
    workflow_path="classification_pipeline.py",
    engine="kfp",
    handler="classification_pipeline"
)

# %%
project.save()

# %%
run_id = project.run(
    name="classification",
    # arguments={
    #     "data_format": "parse_ipzs",
    #     "bucket_name": "ipzs", "idPrefix": "ipzs-", "limit": 10, "max_documents": 100,
    #     "tint_url": None,
    #     "testRatio": 0.2, "devRatio": 0.2
    # }, 
    watch=True
)
# Out:
# > 2023-03-29 15:39:52,119 [info] submitted pipeline document-classification-classification 2023-03-29 13-39-51 id=2bda333c-0020-44bd-a438-84fc38bbbc43
# > 2023-03-29 15:39:52,121 [info] Pipeline run id=2bda333c-0020-44bd-a438-84fc38bbbc43, check UI for progress
# [info] Pipeline started in project document-classification id=2bda333c-0020-44bd-a438-84fc38bbbc43
# > 2023-03-29 15:39:52,224 [info] started run workflow document-classification-classification with run id = '2bda333c-0020-44bd-a438-84fc38bbbc43' by kfp engine
# > 2023-03-29 15:39:52,224 [info] waiting for pipeline run completion
# > 2023-03-29 15:50:36,648 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:50:36,650 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:51:32,758 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:51:32,761 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:52:28,887 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:52:28,889 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:53:25,024 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:53:25,031 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:54:21,160 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:54:21,162 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:55:17,284 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:55:17,289 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:56:13,368 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:56:13,372 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# > 2023-03-29 15:57:09,446 [warning] GET http://127.0.0.1:30070/api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43 request failed on non-retryable exception, raising exception: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)")): {'exception_type': <class 'requests.exceptions.ConnectionError'>, 'exception_message': 'HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host=\'127.0.0.1\', port=30070): Read timed out. (read timeout=10)"))', 'retry_interval': 1, 'retry_count': 0, 'max_retries': 3}
# > 2023-03-29 15:57:09,448 [error] error cannot get pipeline: HTTPConnectionPool(host='127.0.0.1', port=30070): Max retries exceeded with url: /api/v1/projects/document-classification/pipelines/2bda333c-0020-44bd-a438-84fc38bbbc43?namespace=mlrun&format=summary (Caused by ReadTimeoutError("HTTPConnectionPool(host='127.0.0.1', port=30070): Read timed out. (read timeout=10)"))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/nv/5ct0q4651sj58bj94hkvr2wr0000gn/T/ipykernel_92612/2656589945.py in <cell line: 1>()
# ----> 1 run_id = project.run(
#       2     name="classification",
#       3     # arguments={
#       4     #     "data_format": "parse_ipzs",
#       5     #     "bucket_name": "ipzs", "idPrefix": "ipzs-", "limit": 10, "max_documents": 100,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/projects/project.py in run(self, name, workflow_path, arguments, artifact_path, workflow_handler, namespace, sync, watch, dirty, ttl, engine, local, schedule, timeout, overwrite)
#    2048         workflow_spec.clear_tmp()
#    2049         if watch and not workflow_spec.schedule:
# -> 2050             workflow_engine.get_run_status(project=self, run=run, timeout=timeout)
#    2051         return run
#    2052
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/projects/pipelines.py in get_run_status(project, run, timeout, expected_statuses, notifiers)
#     595             if timeout:
#     596                 logger.info("waiting for pipeline run completion")
# --> 597                 state = run.wait_for_completion(
#     598                     timeout=timeout, expected_statuses=expected_statuses
#     599                 )
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/projects/pipelines.py in wait_for_completion(self, timeout, expected_statuses)
#     415
#     416     def wait_for_completion(self, timeout=None, expected_statuses=None):
# --> 417         self._state = self._engine.wait_for_completion(
#     418             self.run_id,
#     419             project=self.project,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/projects/pipelines.py in wait_for_completion(run_id, project, timeout, expected_statuses, run_object)
#     561             timeout = 60 * 60
#     562         project_name = project.metadata.name if project else ""
# --> 563         run_info = wait_for_pipeline_completion(
#     564             run_id,
#     565             timeout=timeout,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/run.py in wait_for_pipeline_completion(run_id, timeout, expected_statuses, namespace, remote, project)
#    1049             )
#    1050
# -> 1051         resp = retry_until_successful(
#    1052             10,
#    1053             timeout,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/utils/helpers.py in retry_until_successful(backoff, timeout, logger, verbose, _function, *args, **kwargs)
#     778         next_interval = next(backoff)
#     779         try:
# --> 780             result = _function(*args, **kwargs)
#     781             return result
#     782
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/run.py in get_pipeline_if_completed(run_id, namespace)
#    1032
#    1033         def get_pipeline_if_completed(run_id, namespace=namespace):
# -> 1034             resp = mldb.get_pipeline(run_id, namespace=namespace, project=project)
#    1035             status = resp["run"]["status"]
#    1036             show_kfp_run(resp, clear_output=True)
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/db/httpdb.py in get_pipeline(self, run_id, namespace, timeout, format_, project)
#    1504             params["format"] = format_
#    1505             project_path = project if project else "*"
# -> 1506             resp = self.api_call(
#    1507                 "GET",
#    1508                 f"projects/{project_path}/pipelines/{run_id}",
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/db/httpdb.py in api_call(self, method, path, error, params, body, json, headers, timeout, version)
#     206
#     207         try:
# --> 208             response = self.session.request(
#     209                 method, url, timeout=timeout, verify=False, **kw
#     210             )
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/utils/http.py in request(self, method, url, **kwargs)
#      85         while True:
#      86             try:
# ---> 87                 response = super().request(method, url, **kwargs)
#      88                 return response
#      89             except Exception as exc:
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/http/client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/http/client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/http/client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Deploy the models

# %%
serving_fn = mlrun.new_function("model-server", kind="serving", image="ertomaselli/classification-tqdm-stanza-fasttext:latest", project="document-classification")

#model_path = training_run.outputs["allTokens_unfiltered_model"]
model_path = "./allTokens_unfiltered_model.bin" #test with single local model

# set the topology/router and add models
graph = serving_fn.set_topology("router")
serving_fn.add_model("allTokens_unfiltered_model", model_path=model_path, class_name="model_serving.ClassifierModel")

project.set_function(serving_fn)
project.save()

# %%
#test function locally
server = serving_fn.to_mock_server()
# Out:
# > 2023-03-30 11:45:02,105 [warning] run command, file or code were not specified
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# INFO:root:extra_data: {}
# > 2023-03-30 11:45:03,672 [info] model allTokens_unfiltered_model was loaded
# > 2023-03-30 11:45:03,672 [info] Loaded ['allTokens_unfiltered_model']

# %%
csv_path = "/Users/erica/document-classification/input-folder/atti_materie_SG_nov2021.csv"
text = "Norme in materia tributaria, di previdenza, di assunzioni nella pubblica amministrazione ed altre disposizioni urgenti."

server.test("/v2/models/allTokens_unfiltered_model/infer", body={"inputs": [csv_path, text]})
# Out:
# 2023-03-30 11:45:34 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 32.7MB/s]
# 2023-03-30 11:45:35 INFO: Loading these models for language: it (Italian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | mwt       | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# INFO:stanza:Loading these models for language: it (Italian):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | mwt       | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2023-03-30 11:45:35 INFO: Use device: cpu
# INFO:stanza:Use device: cpu
# 2023-03-30 11:45:35 INFO: Loading: tokenize
# INFO:stanza:Loading: tokenize
# 2023-03-30 11:45:35 INFO: Loading: mwt
# INFO:stanza:Loading: mwt
# 2023-03-30 11:45:35 INFO: Loading: pos
# INFO:stanza:Loading: pos
# 2023-03-30 11:45:35 INFO: Loading: lemma
# INFO:stanza:Loading: lemma
# 2023-03-30 11:45:35 INFO: Done loading processors!
# INFO:stanza:Done loading processors!
# INFO:root:materie_dict: {'A3840': 'ISTRUZIONE PUBBLICA', 'A4040': 'MAFIA IN GENERE', 'C3H41': "VITTIME DEL TERRORISMO E DELLA CRIMINALITA' ORGANIZZATA", 'A0400': "ANTICHITA' E BELLE ARTI", 'C0I90': 'BENI CULTURALI', 'A0260': 'ALBANIA', 'A1810': 'CONVENZIONI E TRATTATI INTERNAZIONALI', 'A4210': 'MILITARE', 'C0VG2': 'COOPERAZIONE INTERNAZIONALE', 'A5230': 'PROCEDIMENTO PENALE', 'C2L80': 'PROCESSO', 'C3EZ0': 'TRATTATI INTERNAZIONALI', 'A6040': "SANITA' PUBBLICA", 'A6900': 'TURISMO', 'C0RH1': 'COMMISSIONI VARIE', 'A4400': 'NAVE', 'A4310': 'MONETA (ORDINAMENTO MONETARIO E ISTITUTO DI EMISSIONE)', 'A0330': 'AMMINISTRAZIONE DELLO STATO E DEGLI ENTI PUBBLICI IN GENERE', 'S060': "AMMINISTRAZIONE DEL COMMERCIO CON L'ESTERO", 'A0430': 'APPALTO', 'A1490': "COMUNITA' EUROPEE, CONSIGLIO D'EUROPA E PARLAMENTO EUROPEO", 'C1G10': 'EQUIPAGGIO', 'A1290': 'CINEMATOGRAFO E CINEMATOGRAFIA', 'R0SG0': 'INTERVENTI A FAVORE DELLE INDUSTRIE', 'A2530': 'ECONOMIA NAZIONALE E PROGRAMMAZIONE ECONOMICA', 'C1QP0': 'INDUSTRIA', 'A4610': 'ONORIFICENZE E ORDINI CAVALLERESCHI', 'A5370': 'PUBBLICA SICUREZZA', 'A3580': 'INFORTUNI SUL LAVORO E MALATTIE PROFESSIONALI', 'A3910': 'LAVORO (RAPPORTO DI)', 'A5860': 'RICERCA SCIENTIFICA E TECNOLOGICA', 'A1980': 'CREDITO INDUSTRIALE E COMMERCIALE', 'C0ZN0': 'CREDITO ALLE MEDIE E PICCOLE INDUSTRIE', 'A6560': 'STRANIERO', 'A4260': 'MINORE AGLI EFFETTI CIVILI', 'A1390': 'COMITATO', 'C1UT0': 'LAVORO NOTTURNO', 'C3DM0': 'TELEVISIONE', 'A5490': 'RADIOTELEVISIONE E SERVIZI RADIOELETTRICI', 'A2580': 'ELEZIONI', 'C1H20': "ESTERO (ATTI E CONTRATTI RICEVUTI ALL')", 'A4180': 'MERCATO', 'A4710': 'ORO E METALLI PREZIOSI (TITOLO, MARCHIO E COMMERCIO)', 'A1190': 'CATASTO', 'A6935': "UNIVERSITA' DEGLI STUDI", 'C1ON0': 'IMBALLAGGI PRECONFEZIONATI E BOTTIGLIE RECIPIENTI-MISURA', 'A0290': 'ALIMENTI E BEVANDE (IGIENE E COMMERCIO)', 'C1UB0': 'LATTE', 'A6840': 'TRIBUTI IN GENERE', 'A3565': 'INFORMATICA E TELEMATICA', 'C1PI0': 'IMPOSTE E TASSE IN GENERE', 'S141': 'ENTI ED ORGANI VARI', 'A1990': 'CREDITO NAVALE', 'R0SB0': 'CANTIERISTICA NAVALE', 'A0680': 'ATTO AMMINISTRATIVO', 'A0850': 'BANCA', 'A6255': 'SICUREZZA PUBBLICA', 'C1B30': 'DICHIARAZIONE DEI REDDITI', 'C1MA0': 'FORZE ARMATE', 'A2500': 'DONNA (CONDIZIONE GIURIDICA IN GENERE)', 'A0370': 'ANIMALI (PROTEZIONE DEGLI)', 'A1410': 'COMMERCIO (DISCIPLINA DEL)', 'C0NE0': 'CASA DI CURA PRIVATA', 'A6440': 'SPETTACOLI E TRATTENIMENTI PUBBLICI (IMPOSTA SUGLI)', 'A5170': 'PREVIDENZA E ASSISTENZA SOCIALE', 'C1RN0': 'INTEGRAZIONE SALARIALE', 'A4660': 'ORDINAMENTO PENITENZIARIO', 'A4430': 'NAVIGAZIONE MARITTIMA ED INTERNA (ORDINAMENTO AMMINISTRATIVO DELLA)', 'A7000': 'VALORE AGGIUNTO (IMPOSTA SUL) (I.V.A.)', 'A0250': 'AGRICOLTURA', 'C1T60': 'I.V.A. (IMPOSTA SUL VALORE AGGIUNTO)', 'C1HZ0': 'ESPROPRIAZIONE FORZATA', 'A7010': 'VENDITA', 'A2740': 'ESECUZIONE FORZATA PER OBBLIGAZIONI PECUNIARIE', 'C0HV0': 'AUTOTRASPORTI', 'A0720': 'AUTOSERVIZI', 'A3310': "GIUOCHI DI ABILITA' E CONCORSI PRONOSTICI (IMPOSTA SUI)", 'C1UO0': 'LAVORO DELLE DONNE E DEI FANCIULLI', 'R1LU0': 'locati', 'C2RG0': "RILASCIO D'IMMOBILI", 'A4010': 'LOCAZIONE', 'A4630': 'OPERE PUBBLICHE', 'RL003': 'RLRCC', 'A3470': 'IMPRESA E IMPRENDITORE', 'C1UE0': 'LAVORI PUBBLICI', 'A4650': 'ORDINAMENTO GIUDIZIARIO', 'C0UG0': 'CONSIGLIO SUPERIORE DELLA MAGISTRATURA', 'C2Q90': 'RIFIUTI (SMALTIMENTO)', 'A6765': 'TRASPORTI (IN GENERE)', 'C2U90': 'SICUREZZA DEI MEZZI DI TRASPORTO E DI COMUNICAZIONE', 'A3100': 'FIERE, MOSTRE ED ESPOSIZIONI', 'C0FG2': 'ASSISTENZA SANITARIA', 'A2880': 'FABBRICAZIONE (IMPOSTE DI)', 'A3380': 'GUARDIA DI FINANZA', 'C0VI0': 'CORPO DEGLI AGENTI DI CUSTODIA', 'A5260': 'PROFUGHI', 'A3860': "LAVORO (COLLOCAMENTO E MOBILITA' DELLA MANO D'OPERA)", 'A4140': "MATERNITA' E INFANZIA", 'A2470': 'DOGANA', 'A1550': 'CONCORSO A PUBBLICO IMPIEGO', 'C2CS0': 'MUSEI, GALLERIE E SCAVI', 'A4200': 'MEZZOGIORNO (PROVVEDIMENTI PER IL)', 'S045': "AMMINISTRAZIONE DELL'AMBIENTE", 'C1C61': 'DISABILI', 'C0ID0': 'AZIENDE DI CREDITO', 'C2NP0': "PUBBLICITA'", 'A0 ...
# INFO:root:res: (('__label__A1810', '__label__A0300', '__label__A3840', '__label__A1688', '__label__A2520', '__label__A6765', '__label__A0330', '__label__A3470', '__label__A4210', '__label__A6040', '__label__A0675', '__label__A7040'), array([4.64219868e-01, 4.26793933e-01, 6.26340285e-02, 2.07700748e-02,
#        1.58481430e-02, 6.03964925e-03, 1.57000718e-03, 1.31633983e-03,
#        5.06890588e-04, 2.77138985e-04, 1.21764693e-04, 2.21158843e-05]))
# INFO:root:data: {'sentences': [{'tokens': [{'index': 1, 'originalText': 'Norme', 'word': 'Norme', 'featuresText': '_', 'characterOffsetBegin': 0, 'characterOffsetEnd': 5, 'isMultiwordToken': False, 'isMultiwordFirstToken': False, 'pos': 
 'isMultiwordToken': False, 'isMultiwordFirstToken': False, 'pos': 'CC', 'ud_pos': 'CCONJ', 'lemma': 'e'}, {'index': 16, 'originalText': 'altre', 'word': 'altre', 'featuresText': '_', 'characterOffsetBegin': 92, 'characterOffsetEnd': 97, 'isMultiwordToken': False, 'isMultiwordFirstToken': False, 'pos': 'A', 'ud_pos': 'ADJ', 'lemma': 'altro'}, {'index': 17, 'originalText': 'disposizioni', 'word': 'disposizioni', 'featuresText':  ...
# {'id': '055290e59c0841e6b9a84fdfe8175bc6',
#  'model_name': 'allTokens_unfiltered_model',
#  'outputs': ['{"topics": {"A1810 - CONVENZIONI E TRATTATI INTERNAZIONALI": 0.464219868183136, "A0300 - AMBIENTE (TUTELA DELL\')": 0.4267939329147339, "A3840 - ISTRUZIONE PUBBLICA": 0.06263402849435806, "A1688 - CONTABILITA\' E BILANCIO": 0.020770074799656868, "A2520 - ECONOMIA E FINANZA": 0.01584814302623272}, "words": [{"tokens": [{"index": 1, "originalText": "Norme", "word": "Norme", "featuresText": "_", "characterOffsetBegin": 0, "characterOffsetEnd": 5, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "S", "ud_pos": "NOUN", "lemma": "norma"}, {"index": 2, "originalText": "in", "word": "in", "featuresText": "_", "characterOffsetBegin": 6, "characterOffsetEnd": 8, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "E", "ud_pos": "ADP", "lemma": "in"}, {"index": 3, "originalText": "materia", "word": "materia", "featuresText": "_", "characterOffsetBegin": 9, "characterOffsetEnd": 16, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "S", "ud_pos": "NOUN", "lemma": "materia"}, {"index": 4, "originalText": "tributaria", "word": "tributaria", "featuresText": "_", "characterOffsetBegin": 17, "characterOffsetEnd": 27, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "A", "ud_pos": "ADJ", "lemma": "tributario"}, {"index": 5, "originalText": ",", "word": ",", "featuresText": "_", "characterOffsetBegin": 27, "characterOffsetEnd": 28, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "FF", "ud_pos": "PUNCT", "lemma": ","}, {"index": 6, "originalText": "di", "word": "di", "featuresText": "_", "characterOffsetBegin": 29, "characterOffsetEnd": 31, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "E", "ud_pos": "ADP", "lemma": "di"}, {"index": 7, "originalText": "previdenza", "word": "previdenza", "featuresText": "_", "characterOffsetBegin": 32, "characterOffsetEnd": 42, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "S", "ud_pos": "NOUN", "lemma": "previdenza"}, {"index": 8, "originalText": ",", "word": ",", "featuresText": "_", "characterOffsetBegin": 42, "characterOffsetEnd": 43, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "FF", "ud_pos": "PUNCT", "lemma": ","}, {"index": 9, "originalText": "di", "word": "di", "featuresText": "_", "characterOffsetBegin": 44, "characterOffsetEnd": 46, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "E", "ud_pos": "ADP", "lemma": "di"}, {"index": 10, "originalText": "assunzioni", "word": "assunzioni", "featuresText": "_", "characterOffsetBegin": 47, "characterOffsetEnd": 57, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "S", "ud_pos": "NOUN", "lemma": "assunzione"}, {"index": 11, "originalText": "nella", "word": "in", "characterOffsetBegin": 58, "characterOffsetEnd": 63, "featuresText": null, "isMultiwordToken": true, "isMultiwordFirstToken": true, "pos": "E", "ud_pos": "ADP", "lemma": "in"}, {"index": 12, "originalText": "nella", "word": "la", "characterOffsetBegin": 58, "characterOffsetEnd": 63, "featuresText": "Definite=Def|Gender=Fem|Number=Sing|PronType=Art", "isMultiwordToken": true, "isMultiwordFirstToken": false, "pos": "RD", "ud_pos": "DET", "lemma": "il"}, {"index": 13, "originalText": "pubblica", "word": "pubblica", "featuresText": "_", "characterOffsetBegin": 64, "characterOffsetEnd": 72, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "A", "ud_pos": "ADJ", "lemma": "pubblico"}, {"index": 14, "originalText": "amministrazione", "word": "amministrazione", "featuresText": "_", "characterOffsetBegin": 73, "characterOffsetEnd": 88, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "S", "ud_pos": "NOUN", "lemma": "amministrazione"}, {"index": 15, "originalText": "ed", "word": "ed", "featuresText": "_", "characterOffsetBegin": 89, "characterOffsetEnd": 91, "isMultiwordToken": false, "isMultiwordFirstToken": false, "pos": "CC", "ud_pos": "CCONJ", "lemma": "e"}, {"index": 16, "originalText": "al ...

# %%
#serving_fn.deploy()
mlrun.deploy_function(serving_fn)
# Out:
# > 2023-03-30 13:40:58,559 [info] Starting remote function deploy
# 2023-03-30 11:40:58  (info) Deploying function
# 2023-03-30 11:40:58  (info) Building
# 2023-03-30 11:40:58  (info) Staging files and preparing base images
# 2023-03-30 11:40:58  (info) Building processor image
# Failed to deploy. Details:
#
# Error - Job failed. Job logs:
# error checking push permissions -- make sure you entered the correct tag name, and that you are authenticated correctly, and try again: checking push permission for "index.docker.io/smartcommunitylab/processor-document-classification-model-server:latest": POST https://index.docker.io/v2/smartcommunitylab/processor-document-classification-model-server/blobs/uploads/: UNAUTHORIZED: authentication required; [map[Action:pull Class: Name:smartcommunitylab/processor-document-classification-model-server Type:repository] map[Action:push Class: Name:smartcommunitylab/processor-document-classification-model-server Type:repository]]
#     /nuclio/pkg/processor/build/builder.go:263
#
# Call stack:
# Failed to build processor image
#     /nuclio/pkg/processor/build/builder.go:263
#
# > 2023-03-30 13:41:24,561 [error] Nuclio function failed to deploy: {'function_state': 'error'}
# ---------------------------------------------------------------------------
# RunError                                  Traceback (most recent call last)
# /var/folders/nv/5ct0q4651sj58bj94hkvr2wr0000gn/T/ipykernel_92612/4176811065.py in <cell line: 2>()
#       1 #serving_fn.deploy()
# ----> 2 mlrun.deploy_function(serving_fn)
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/projects/operations.py in deploy_function(function, dashboard, models, env, tag, verbose, builder_env, project_object, mock)
#     343             )
#     344
# --> 345         address = function.deploy(
#     346             dashboard=dashboard, tag=tag, verbose=verbose, builder_env=builder_env
#     347         )
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/runtimes/serving.py in deploy(self, dashboard, project, tag, verbose, auth_info, builder_env)
#     621             logger.info(f"deploy root function {self.metadata.name} ...")
#     622
# --> 623         return super().deploy(
#     624             dashboard, project, tag, verbose, auth_info, builder_env=builder_env
#     625         )
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/runtimes/function.py in deploy(self, dashboard, project, tag, verbose, auth_info, builder_env)
#     550             self.status = data["data"].get("status")
#     551             self._update_credentials_from_remote_build(data["data"])
# --> 552             self._wait_for_function_deployment(db, verbose=verbose)
#     553
#     554             # NOTE: on older mlrun versions & nuclio versions, function are exposed via NodePort
#
# ~/opt/anaconda3/envs/classificationenv/lib/python3.9/site-packages/mlrun/runtimes/function.py in _wait_for_function_deployment(self, db, verbose)
#     620         if state != "ready":
#     621             logger.error("Nuclio function failed to deploy", function_state=state)
# --> 622             raise RunError(f"function {self.metadata.name} deployment failed")
#     623
#     624     @min_nuclio_versions("1.5.20", "1.6.10")
#
# RunError: function model-server deployment failed
